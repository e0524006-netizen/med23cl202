# %% [markdown]
# <a href="https://colab.research.google.com/github/e0524006-netizen/med23cl202/blob/main/exp6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data={
    "student":["stu1","stu2","stu3","stu4","stu5"],
    "feespaid ":[1000,1200,1400,900,1500]
}
df=pd.DataFrame(data)
sns.barplot (x="student",y="feespaid ",data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde

fees = [48000,43200,45600,38400,48000]
density = gaussian_kde(fees)
xs = np.linspace(min(fees), max(fees), 200)

plt.plot(xs,density(xs))
plt.show()

# %%
fees :[1000,1200,1400,900,1500]

plt.boxplot (fees)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fees = [1000,1200,1400,900,1500]

sns.histplot (fees)
plt.show()
